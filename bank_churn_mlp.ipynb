# %% [markdown]
# # Bank Churn Prediction using MLP (NumPy Implementation)
# ## تمرین اول برنامه نویسی درس یادگیری عمیق
# ### University of Kurdistan - Department of Computer and IT Engineering

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Generate Dataset

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ## 4. MLP Model Implementation

# %% [markdown]
# ## 5. Training

# %% [markdown]
# ## 6. Evaluation

# %% [markdown]
# ## 7. Experiments
# ### 7.1 Activation Functions Comparison

# %% [markdown]
# ### 7.2 Learning Rate Experiments

# %% [markdown]
# ### 7.3 Hidden Layer Size Analysis

# %% [markdown]
# ### 7.4 Regularization (L2 & Dropout)

# %% [markdown]
# ## 8. Feature Importance Analysis

# %% [markdown]
# ## 9. Visualization & Results
